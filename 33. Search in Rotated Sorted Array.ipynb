# %%
nums = [4,5,6,7,0,1,2]
target = 0
# nums = [3,1]
# target = 3

# %%
def sol(nums, target):

    l, r = 0, len(nums)-1

    while l <= r:
        print(l,r)

        m = (l+r)//2
        if nums[m] == target:
            return m

        # мы в левой сорт части
        if nums[m] >= nums[l]: 
            # если ответ больше - ищем его справа
            if num[m] < target:
                l = m + 1
            # если ответ меньше, но и меньше левого значения - ищем его справа
            elif target < num[m] and target < num[l]:
                l = m + 1
            # если ответ меньше, но больше левого значени - ищем его слева
            else:
                r = m - 1
        
        # мы в правой  сорт части 
        else:
            # если ответ меньше - ищем его слева
            if target < nums[m]:
                r = m - 1
            # если ответ больше, но и больше правого значения - ищем его слева
            elif nums[m] < target and nums[r] < r:
                r = m - 1
            # если ответ больше - ищем его слева
            else:
                l = m + 1

# %%
sol(nums, target)
# Out:
# 0 6
# 4 6
# 5

# %%
nums = [4,5,6,7,0,1,2]
target = 0
# nums = [3,1]
# target = 3

# %%
def sol(nums, target):

    l, r = 0, len(nums)-1

    while l <= r:
        print(l,r)

        m = (l+r)//2
        if nums[m] == target:
            return m

        # мы в левой сорт части
        if nums[m] >= nums[l]: 
            # если ответ больше - ищем его справа
            if nums[m] < target:
                l = m + 1
            # если ответ меньше, но и меньше левого значения - ищем его справа
            elif target < nums[l]:
                l = m + 1
            # если ответ меньше - ищем его слева
            else:
                r = m - 1
        
        # мы в правой  сорт части 
        else:
            # если ответ меньше - ищем его слева
            if target < nums[m]:
                r = m - 1
            # если ответ больше, но и больше правого значения - ищем его слева
            elif nums[r] < target:
                r = m - 1
            # если ответ больше - ищем его справа
            else:
                l = m + 1
            

    return -1

# %%
sol(nums, target)
# Out:
# 0 6
# 4 6
# 4 4
# 4

# %%
def sol(nums, target):

    l, r = 0, len(nums)-1

    while l <= r:
        print(l,r)

        m = (l+r)//2
        if nums[m] == target:
            return m

        # мы в левой сорт части
        if nums[m] >= nums[l]: 
            # если ответ больше - ищем его справа
            # или
            # если ответ меньше, но и меньше левого значения - ищем его справа
            if nums[m] < target or target < nums[l]:
                l = m + 1

            # если ответ меньше - ищем его слева
            else:
                r = m - 1
        
        # мы в правой  сорт части 
        else:
            # если ответ меньше - ищем его слева
            # или
            # если ответ больше, но и больше правого значения - ищем его слева
            if target < nums[m] or nums[r] < target:
                r = m - 1

            # если ответ больше - ищем его справа
            else:
                l = m + 1
            

    return -1

# %%
sol(nums, target)
# Out:
# 0 6
# 4 6
# 4 4
# 4

# %%
def sol(nums, target):

    l, r = 0, len(nums)-1
    while l <= r:

        m = (l+r)//2
        
        if nums[m] == target:
            return m

        if nums[m] >= nums[l]: 

            if nums[m] < target or target < nums[l]:
                l = m + 1
            else:
                r = m - 1
        
        else:
            
            if target < nums[m] or nums[r] < target:
                r = m - 1
            else:
                l = m + 1
            

    return -1
