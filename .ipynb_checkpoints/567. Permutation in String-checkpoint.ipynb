# %%
s1 = "ab"
s2 = "eidbaooo"

# %%
def sol(s1, s2):

    l = 0
    n = len(s2)
    
    needed = set(s1)

    collected = []


    for r in range(n):

        if s2[r] not in needed:
            l = r

        collected.append(s2[r])
        
    return collected
