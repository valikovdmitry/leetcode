# %%
strs = ["we","say",":","yes"]

# %%
def encode(strs):
    res = []

    for string in strs:
        
        res.append(str(len(string)))
        res.append('#')
        res.append(string)

    return ''.join(res)

# %%
encode(strs)
# Out:
# '2$we3$say1$:3$yes'

# %%
def decode(str):
    res = []
    
    i = 0
    while i < len(s):
        j = i
        
        while s[j] != '#':
            j += 1

        length = int(s[i:j])

        i = j + 1
        word = s[i:i + length]

        res.append(word)
        
        i += length
        

    return res

# %%
decode(encode(strs))
# Out:
# ['we', 'say', ':', 'yes']
