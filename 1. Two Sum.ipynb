# %%
def s(nums, target):
    solution = None
    idx = 0
    current_num = nums[idx]
    
    while not solution:
        for i in range(idx + 1, len(nums)):
            summ = nums[idx] + nums[i]
            print(idx, i)
            print(summ)
            if summ == target:
                solution = [idx, i]
                return solution
    
        idx += 1

def s2(nums, target):
    d = dict()

    for i in range(len(nums)):
        if nums[i] in d:
            return [d[nums[i]], i]
        d[target - nums[i]] = i

# %%
nums = [3,2,3]
target = 6
s2(nums, target)
# Out:
# [0, 2]

# %%
nums = [11,15,2,7]
target = 9
s2(nums, target)
# Out:
# [2, 3]

# %%
nums = [3,2,4] 
target = 6
s2(nums, target)
# Out:
# [1, 2]
