# %%
def req(num):
    
    print(num)

    if num == 1:
        return num

    return num * req(num - 1)

# %%
req(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 120

# %%
nums = [-1,0,3,4,5,9,12]
target = 9

# %%
def search(nums, target):

    i = len(nums) // 2

# %%
search(nums, target)
# Out:
# 3 4
# 2 9
# 2
