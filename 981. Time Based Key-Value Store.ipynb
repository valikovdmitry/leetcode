# %%
class TimeMap:

    def __init__(self):
        self.hashTable = {}

    def set(self, key: str, value: str, timestamp: int) -> None:
        if key not in self.hashTable:
            self.hashTable[key] = []
        self.hashTable[key].append((timestamp, value))

    def get(self, key: str, timestamp: int) -> str:

        res = ''
        values = self.hashTable.get(key, [])

        l,r = 0, len(data)-1
        while l <= r:
            m = (l+r)//2
            if data[m][0] == timestamp:
                return data[m][1]
            elif data[m][0] < timestamp:
                res = data[m][1]
                l = m + 1
            else:
                r = m - 1
            

        return res

# %%
obj = TimeMap()

# %%
obj.set('key1','e',5)

# %%
obj.hashTable
# Out:
# {'key1': [(5, 'e')]}

# %%
data = obj.hashTable['key1']

# %%
data
# Out:
# [(5, 'e')]

# %%
data = [(1, 'a'), (2, 'b'), (3, 'c'), (7, 'd'), (8, 'e')]

# %%
time = 4

# %%
def sol2(data, time):

    l,r = 0,len(data)-1
    resTime = data[0][0]

    while l <= r:
        m = (l+r)//2

        if time < data[m][0]:
            r = m - 1
        elif data[m][0] <= time:
            resTime = max(resTime, data[m][0])
            l = m + 1

    return resTime

# %%
sol2(data, time)
# Out:
# 3

# %%
["TimeMap",   "set",                "set",              "get",       "get",        "get",        "get",        "get"]

# %%
[[],          ["love","high",10],  ["love","low",20],  ["love",5],  ["love",10],  ["love",15],  ["love",20],  ["love",25]]

# %%
[null,         null,                null,               "high",      "low",        "low",        "low",        "low"]

# %%
[null,         null,                null,               "",          "high",       "high",       "low",        "low"]
